# %% [markdown]
# Exercise 1 (Plotting cell shapes, 10 points). Plot one of the cells by plotting the landmark points
# and interpolating between subsequent landmark points.
# Next, plot all the cells on top of each other. Can you see any dataset tendencies from this plot?
# When plotting, make sure to make the axes equal to get the right dimensions. If you use matplotlyb.pyplot
# this can be done by typing plt.axis('equal').

# %%
#Exercise 1
import numpy as np
import matplotlib.pyplot as plt
diatoms = np.loadtxt("diatoms.txt")
col = np.shape(diatoms)[1]
x_coord = diatoms[:, 0:col:2]
y_coord = diatoms[:, 1:col:2]

plt.plot(x_coord[0], y_coord[0])
plt.axis('equal')
# Out:
# (-18.68975, 18.68935, -3.903577, 3.948157)

# %%
for i in range(len(x_coord)):
    plt.plot(x_coord[i], y_coord[i])
plt.axis('equal')
# Out:
# (-19.775095, 19.747795, -11.505120000000002, 11.58652)

# %%
diatom_T = np.concatenate((x_coord.T, y_coord.T))
mean_diatom = np.mean(diatom_T, 1)
cov_matrix = np.cov(diatom_T)
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

pc1 = eigenvectors[:,0]
eigenvalue1 = eigenvalues[0]
std1 = np.sqrt(eigenvalue1)

diatoms_along_pc = np.zeros((5,180))
for i in range(5):
    diatoms_along_pc[i,:] = mean_diatom + (i-2)*std1*pc1
    plt.plot(diatoms_along_pc[i, :90], diatoms_along_pc[i, 90:], label = i, color = (0,i/5,i/5))
plt.legend()
plt.show()
